# %% [markdown]
# <a href="https://colab.research.google.com/github/pankajjadhav2505/python/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Write a Python program to print all the even numbers between 20 and 50.

for num in range(20, 51):
  if num % 2 == 0:
    print(num)

# %%
# Write a Python program to calculate the factorial of a number using recursion.
# Take the number as input from the user.

# Write a Python program to print all the even numbers between 20 and 50.

for num in range(20, 51):
  if num % 2 == 0:
    print(num)

def factorial(n):
  """
  Calculate the factorial of a number using recursion.
  """
  if n == 0:
    return 1
  else:
    return n * factorial(n-1)

# Take input from the user
num = int(input("Enter a number: "))

# Calculate the factorial
result = factorial(num)

# Print the result
print("The factorial of", num, "is", result)
print();

# %%
# Write a Python program that takes a list of numbers [10, 50, 16, 29, 13, 20, 56, 96,
# 23] and interchanges the positions of the first and last elements. Display the
# modified list.

# Write a Python program to print all the even numbers between 20 and 50.

for num in range(20, 51):
  if num % 2 == 0:
    print(num)

# Write a Python program to calculate the factorial of a number using recursion.
# Take the number as input from the user.

# Write a Python program to print all the even numbers between 20 and 50.

for num in range(20, 51):
  if num % 2 == 0:
    print(num)

def factorial(n):
  """
  Calculate the factorial of a number using recursion.
  """
  if n == 0:
    return 1
  else:
    return n * factorial(n-1)

# Take input from the user
num = int(input("Enter a number: "))

# Calculate the factorial
result = factorial(num)

# Print the result
print("The factorial of", num, "is", result)
print();

# Write a Python program that takes a list of numbers [10, 50, 16, 29, 13, 20, 56, 96,
# 23] and interchanges the positions of the first and last elements. Display the
# modified list.

numbers = [10, 50, 16, 29, 13, 20, 56, 96, 23]
first = numbers[0]
last = numbers[-1]
numbers[0] = last
numbers[-1] = first
print(numbers)

# %%
# Write a Python program to find the reverse of a string without using any built-in
# string reverse functions. Take the string as input from the user.

# Take input from the user
string = input("Enter a string: ")

# Initialize an empty string to store the reversed string
reversed_string = ""

# Iterate through the string in reverse order
for i in range(len(string) - 1, -1, -1):
  reversed_string += string[i]

# Print the reversed string
print("Reversed string:", reversed_string)

# %%
# Write a Python program to find the smallest among three numbers. Take the
# numbers as input from the user.

# Take input from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))

# Find the smallest number
if num1 <= num2 and num1 <= num3:
  smallest = num1
elif num2 <= num1 and num2 <= num3:
  smallest = num2
else:
  smallest = num3

# Print the result
print("The smallest number is:", smallest)

# %%
# Write a Python program to calculate the average of a list of numbers `[4, 6, 8, 10]`

# Write a Python program to print all the even numbers between 20 and 50.

for num in range(20, 51):
  if num % 2 == 0:
    print(num)

# Write a Python program to calculate the factorial of a number using recursion.
# Take the number as input from the user.

# Write a Python program to print all the even numbers between 20 and 50.

for num in range(20, 51):
  if num % 2 == 0:
    print(num)

def factorial(n):
  """
  Calculate the factorial of a number using recursion.
  """
  if n == 0:
    return 1
  else:
    return n * factorial(n-1)

# Take input from the user
num = int(input("Enter a number: "))

# Calculate the factorial
result = factorial(num)

# Print the result
print("The factorial of", num, "is", result)
print();

# Write a Python program that takes a list of numbers [10, 50, 16, 29, 13, 20, 56, 96,
# 23] and interchanges the positions of the first and last elements. Display the
# modified list.

# Write a Python program to print all the even numbers between 20 and 50.

for num in range(20, 51):
  if num % 2 == 0:
    print(num)

# Write a Python program to calculate the factorial of a number using recursion.
# Take the number as input from the user.

# Write a Python program to print all the even numbers between 20 and 50.

for num in range(20, 51):
  if num % 2 == 0:
    print(num)

def factorial(n):
  """
  Calculate the factorial of a number using recursion.
  """
  if n == 0:
    return 1
  else:
    return n * factorial(n-1)

# Take input from the user
num = int(input("Enter a number: "))

# Calculate the factorial
result = factorial(num)

# Print the result
print("The factorial of", num, "is", result)
print();

# Write a Python program that takes a list of numbers [10, 50, 16, 29, 13, 20, 56, 96,
# 23] and interchanges the positions of the first and last elements. Display the
# modified list.

numbers = [10, 50, 16, 29, 13, 20, 56, 96, 23]
first = numbers[0]
last = numbers[-1]
numbers[0] = last
numbers[-1] = first
print(numbers)


# Take input from the user
string = input("Enter a string: ")

# Initialize an empty string to store the reversed string
reversed_string = ""

# Iterate through the string in reverse order
for i in range(len(string) - 1, -1, -1):
  reversed_string += string[i]

# Print the reversed string
print("Reversed string:", reversed_string)


# Take input from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))

# Find the smallest number
if num1 <= num2 and num1 <= num3:
  smallest = num1
elif num2 <= num1 and num2 <= num3:
  smallest = num2
else:
  smallest = num3

# Print the result
print("The smallest number is:", smallest)

# Calculate the average of a list of numbers
numbers = [4, 6, 8, 10]
total = sum(numbers)
average = total / len(numbers)
print("The average of the list is:", average)

# %%
# Python Program to Add Subtract Multiply and Divide two numbers using a class
# and object.

class Calculator:
    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2

    def add(self):
        return self.num1 + self.num2

    def subtract(self):
        return self.num1 - self.num2

    def multiply(self):
        return self.num1 * self.num2

    def divide(self):
        if self.num2 != 0:
            return self.num1 / self.num2
        else:
            return "Division by zero is not allowed."

# Get input from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Create a Calculator object
calc = Calculator(num1, num2)

# Perform calculations and print the results
print("Sum:", calc.add())
print("Difference:", calc.subtract())
print("Product:", calc.multiply())
print("Quotient:", calc.divide())

# %%
# Define a Python function called `add_numbers` that takes two numbers as
# arguments and returns their sum.

def add_numbers(num1, num2):
  """
  This function takes two numbers as arguments and returns their sum.
  """
  return num1 + num2

# %%
# Write a Python program to print the multiplication table of a number. Take the
# number as input from the user.

# Take input from the user
num = int(input("Enter a number: "))

# Print the multiplication table
print("Multiplication table of", num)
for i in range(1, 11):
  print(num, "x", i, "=", num * i)

# %%
# Write a lambda function that calculates the cube of a given number.

cube = lambda x: x**3
